# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x=data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12187    -117.31     33.67                 9.0        981.0           169.0
# 10286    -117.83     33.89                25.0       1737.0           270.0
# 12592    -121.51     38.52                30.0       3236.0           588.0
# 13569    -117.28     34.14                40.0       2364.0           438.0
# 1256     -121.96     39.30                39.0        701.0           130.0
# ...          ...       ...                 ...          ...             ...
# 15807    -122.44     37.76                52.0       2110.0           454.0
# 18587    -121.80     36.94                29.0       2377.0           476.0
# 5049     -118.38     34.02                31.0       1893.0           450.0
# 14203    -117.05     32.69                 8.0        831.0           158.0
# 15668    -122.44     37.80                52.0       3257.0           735.0
#
#        population  households  median_income ocean_proximity  \
# 12187       596.0       156.0         3.1832       <1H OCEAN
# 10286       840.0       265.0         4.6250       <1H OCEAN
# 12592      1167.0       569.0         4.0972          INLAND
# 13569       968.0       416.0         3.4906          INLAND
# 1256        271.0        89.0         2.1845          INLAND
# ...           ...         ...            ...             ...
# 15807       816.0       438.0         3.9079        NEAR BAY
# 18587      1669.0       499.0         2.8214       <1H OCEAN
# 5049        819.0       426.0         4.3077       <1H OCEAN
# 14203       740.0       154.0         5.3908      NEAR OCEAN
# 15668      1045.0       620.0         4.5523        NEAR BAY
#
#        median_house_value
# 12187            157400.0
# 10286            245700.0
# 12592            181400.0
# 13569             93300.0
# 1256             112500.0
# ...                   ...
# 15807            370000.0
# 18587            190100.0
# 5049             140600.0
# 14203            165500.0
# 15668            500001.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
ts=train_data
train_data=train_data.drop(['ocean_proximity'],axis=1)

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925298           -0.108984     0.045799
# latitude            -0.925298  1.000000            0.013404    -0.037074
# housing_median_age  -0.108984  0.013404            1.000000    -0.359181
# total_rooms          0.045799 -0.037074           -0.359181     1.000000
# total_bedrooms       0.070703 -0.068047           -0.319980     0.928052
# population           0.105278 -0.114031           -0.302663     0.866086
# households           0.058065 -0.073111           -0.302555     0.917459
# median_income       -0.021759 -0.072944           -0.119769     0.200388
# median_house_value  -0.052144 -0.137569            0.103030     0.139311
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070703    0.105278    0.058065      -0.021759
# latitude                 -0.068047   -0.114031   -0.073111      -0.072944
# housing_median_age       -0.319980   -0.302663   -0.302555      -0.119769
# total_rooms               0.928052    0.866086    0.917459       0.200388
# total_bedrooms            1.000000    0.886861    0.980212      -0.009480
# population                0.886861    1.000000    0.915387       0.005875
# households                0.980212    0.915387    1.000000       0.011971
# median_income            -0.009480    0.005875    0.011971       1.000000
# median_house_value        0.054120   -0.021849    0.069656       0.686851
#
#                     median_house_value
# longitude                    -0.052144
# latitude                     -0.137569
# housing_median_age            0.103030
# total_rooms                   0.139311
# total_bedrooms                0.054120
# population                   -0.021849
# households                    0.069656
# median_income                 0.686851
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data['ocean_proximity']=ts['ocean_proximity']
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7262
# INLAND        5154
# NEAR OCEAN    2094
# NEAR BAY      1832
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity, dtype=int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12187          1       0       0         0           0
# 10286          1       0       0         0           0
# 12592          0       1       0         0           0
# 13569          0       1       0         0           0
# 1256           0       1       0         0           0
# ...          ...     ...     ...       ...         ...
# 15807          0       0       0         1           0
# 18587          1       0       0         0           0
# 5049           1       0       0         0           0
# 14203          0       0       0         0           1
# 15668          0       0       0         1           0
#
# [16346 rows x 5 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity, dtype=int)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12187    -117.31     33.67                 9.0     6.889591        5.135798
# 10286    -117.83     33.89                25.0     7.460490        5.602119
# 12592    -121.51     38.52                30.0     8.082402        6.378426
# 13569    -117.28     34.14                40.0     7.768533        6.084499
# 1256     -121.96     39.30                39.0     6.553933        4.875197
# ...          ...       ...                 ...          ...             ...
# 15807    -122.44     37.76                52.0     7.654917        6.120297
# 18587    -121.80     36.94                29.0     7.774015        6.167516
# 5049     -118.38     34.02                31.0     7.546446        6.111467
# 14203    -117.05     32.69                 8.0     6.723832        5.068904
# 15668    -122.44     37.80                52.0     8.088869        6.601230
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12187    6.391917    5.056246         3.1832            157400.0          1
# 10286    6.734592    5.583496         4.6250            245700.0          1
# 12592    7.063048    6.345636         4.0972            181400.0          0
# 13569    6.876265    6.033086         3.4906             93300.0          0
# 1256     5.605802    4.499810         2.1845            112500.0          0
# ...           ...         ...            ...                 ...        ...
# 15807    6.705639    6.084499         3.9079            370000.0          0
# 18587    7.420579    6.214608         2.8214            190100.0          1
# 5049     6.709304    6.056784         4.3077            140600.0          1
# 14203    6.608001    5.043425         5.3908            165500.0          0
# 15668    6.952729    6.431331         4.5523            500001.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12187       0       0         0           0
# 10286       0       0         0           0
# 12592       1       0         0           0
# 13569       1       0         0           0
# 1256        1       0         0           0
# ...       ...     ...       ...         ...
# 15807       0       0         1           0
# 18587       0       0         0           0
# 5049        0       0         0           0
# 14203       0       0         0           1
# 15668       0       0         1           0
#
# [16346 rows x 14 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>,
#         <Axes: title={'center': 'total_rooms'}>],
#        [<Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>],
#        [<Axes: title={'center': 'median_house_value'}>,
#         <Axes: title={'center': '<1H OCEAN'}>,
#         <Axes: title={'center': 'INLAND'}>,
#         <Axes: title={'center': 'ISLAND'}>],
#        [<Axes: title={'center': 'NEAR BAY'}>,
#         <Axes: title={'center': 'NEAR OCEAN'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude',data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"]=train_data["total_bedrooms"]/ train_data["total_rooms"]
train_data["household_rooms"] = train_data['total_rooms'] / train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train = train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity, dtype=int)).drop(['ocean_proximity'], axis=1)

test_data["bedroom_ratio"]=test_data["total_bedrooms"]/ test_data["total_rooms"]
test_data["household_rooms"] = test_data['total_rooms'] / test_data["households"]

# %%
x_test, y_test = test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
reg.score(x_test,y_test)
# Out:
# 0.6666996747348723

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.8202016157699952
